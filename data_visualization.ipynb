# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("HAM10000_metadata.csv")
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
sns.countplot(data=df, x="dx")
plt.title("Number of people of certain types of cancer")
plt.xlabel("types")
plt.ylabel("Number of People")
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("HAM10000_metadata.csv")
cancer = df["dx"]
cancer = np.unique(cancer, return_counts=True)
print(cancer[0])
plt.pie(
    cancer[1],
    labels=[
        "Actinic keratoses",
        "Basal Cell Carcinoma",
        "Benign keratosis-like lesions",
        "Dermatofibroma",
        "Melanoma",
        "Melanocytic nevi",
        "Vascular lesions",
    ],
)
# Out:
# ['akiec' 'bcc' 'bkl' 'df' 'mel' 'nv' 'vasc']
# ([<matplotlib.patches.Wedge at 0x12f935ed0>,
#   <matplotlib.patches.Wedge at 0x12f9341d0>,
#   <matplotlib.patches.Wedge at 0x12f9354d0>,
#   <matplotlib.patches.Wedge at 0x12f937250>,
#   <matplotlib.patches.Wedge at 0x12f935c90>,
#   <matplotlib.patches.Wedge at 0x17424f490>,
#   <matplotlib.patches.Wedge at 0x17424e310>],
#  [Text(1.0767366054910381, 0.225029514498958, 'Actinic keratoses'),
#   Text(0.8153497966944342, 0.7383797864448519, 'Basal Cell Carcinoma'),
#   Text(-0.1984214399415998, 1.081956067579226, 'Benign keratosis-like lesions'),
#   Text(-0.8923565190264395, 0.6431950271504094, 'Dermatofibroma'),
#   Text(-1.0877851339463005, -0.1634732466351281, 'Melanoma'),
#   Text(0.36241318554988233, -1.0385839797241176, 'Melanocytic nevi'),
#   Text(1.0956005215432405, -0.09828274107990354, 'Vascular lesions')])
